# %%
import pandas as pd

# %%
train = pd.read_csv('clean_train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... emb_C emb_Q  emb_S  Fare_usd  \
# 0      0         A/5 21171   7.2500  ...     0     0      1   9.42500
# 1      0          PC 17599  71.2833  ...     1     0      0  92.66829
# 2      0  STON/O2. 3101282   7.9250  ...     0     0      1  10.30250
# ...

# %%
train.groupby('Family_size')['PassengerId'].count()
# Out:
# Family_size
# 0     537
# 1     161
# 2     102
# 3      29
# 4      15
# 5      22
# 6      12
# 7       6
# 10      7
# Name: PassengerId, dtype: int64

# %%
features = train[['Age','Is_female','Pclass','emb_C','emb_Q',
                 'emb_S','Family_size', 'Mr', 'Mrs', 'Master', 'Miss']]
target_s = train.Survived
target_f = train.Fare

# %%
features.head()
# Out:
#     Age  Is_female  Pclass  emb_C  emb_Q  emb_S  Family_size  Mr  Mrs  Master  \
# 0  22.0      False       3      0      0      1            1   1    0       0
# 1  38.0       True       1      1      0      0            1   0    1       0
# 2  26.0       True       3      0      0      1            0   0    0       0
# 3  35.0       True       1      0      0      1            1   0    1       0
# 4  35.0      False       3      0      0      1            0   1    0       0
#
#    Miss
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold, RepeatedStratifiedKFold

# %%
features_train_s, features_test_s, target_train_s, target_test_s = \
    train_test_split(features, target_s, test_size=0.2, random_state=0)
features_train_f, features_test_f, target_train_f, target_test_f = \
    train_test_split(features, target_f, test_size=0.2, random_state=0)

# %%
model_s = RandomForestClassifier()
score_s = cross_val_score(model_s, features, target_s, cv=RepeatedStratifiedKFold()).mean()
model_f = KNeighborsClassifier()
score_f = cross_val_score(model_f, features, target)
score_s
score_f
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     826             try:
# --> 827                 tasks = self._ready_batches.get(block=False)
#     828             except queue.Empty:
#
# ~/opt/anaconda3/lib/python3.7/queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5428e4ccaed7> in <module>
#       1 model = RandomForestClassifier()
#       2 score_s = cross_val_score(model, features, target_s, cv=RepeatedStratifiedKFold()).mean()
# ...
